# %%
"""
============================
Plotting NEAT Classifier
============================

An example plot of :class:`neuro_evolution._neat.NEATClassifier`
"""
from matplotlib import pyplot as plt
# from sklearn.datasets import make_classification
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from neuro_evolution import NEATClassifier
from tensorflow.keras.datasets import cifar10
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.utils import to_categorical
import numpy as np
import cv2
import sys
import logging
from io import StringIO 
import re
import glob
import os
from os.path import dirname, basename, isfile, join
import seaborn as sns

# %matplotlib inline
sns.set_style()

# %%
sys.path.append(os.getcwd()+"/Sklearn-neat")

import neat
from neat import math_util
from neat.puissance import Puissance

# %%
# neat.math_util.mean([5,2,4])

# %%
class Capturing(list):
    def __enter__(self):
        self._stdout = sys.stdout
        sys.stdout = self._stringio = StringIO()
        return self
    def __exit__(self, *args):
        self.extend(self._stringio.getvalue().splitlines())
        del self._stringio    # free up some memory
        sys.stdout = self._stdout

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

X = np.append(x_train,x_test).reshape(60000,32,32,3)
y = np.append(y_train,y_test).reshape(60000,1)

assert X.shape == (60000, 32, 32, 3)
assert y.shape == (60000, 1)

# %%
#Transform (50000, 32, 32, 3) to (50000, 32, 32) with grayscaling.
# x_train = np.array([cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) for image in x_train])
# x_test = np.array([cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) for image in x_test])

#Preprocess the data
X = X.astype('float32')
X /= 255

# %%
from sklearn.model_selection import StratifiedShuffleSplit

sss = StratifiedShuffleSplit(n_splits=5, 
                             test_size=0.0002, 
                             train_size=0.0002, 
                             random_state=0)

for train_index, test_index in sss.split(X, y):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
# Out:
# TRAIN: [48093  9803 26659 43338 44180 51523 18710 53793 39885 49231  9806  2128] TEST: [14856 15275 31434 47947 25917  5066   841 36690 57014 46225 56127 44327]
# TRAIN: [26388 43834 52340 18482  3061 26549 33849 16855 11320 49735  9188 47962] TEST: [ 9941 41405 12326 42032 16005 46627 54866 29921 49630 26332 21829 17770]
# TRAIN: [ 3717 41679 59177  3795 34353 53449 35354 17940 17588 59993 25303 59452] TEST: [57165 57427 10161 37000 36501  8154 21509 46268 44446  3328 58129 30380]
# TRAIN: [53109 36718 50230 10039 10029  9903  4721 37819  1440 20407  8474 52362] TEST: [30537 29262 51315 52585  7090 59817 33987 44205  4947 16192 37981 17929]
# TRAIN: [34368 13090 51681 58455  8036 11286  5697 15198 48070  6217 32912 13134] TEST: [ 3877 48548 17664 45418 41613 34458 51295 33566 15584 20466 11515 12843]

# %%
print(X_train.shape)
print(y_train.shape)

print("---")

print(X_test.shape)
print(y_test.shape)
# Out:
# (12, 32, 32, 3)
# (12, 1)
# ---
# (12, 32, 32, 3)
# (12, 1)

# %%
def find_metric_in_output(output, string):    
    result = re.findall(r"\b"+string+r" ([0-9]+\.[0-9]+)\b", str(output))
    result = np.array(result).astype('float')
    result = result[0]
    
    return result

X_train_fl = X_train.reshape((X_train.shape[0], -1))
X_test_fl = X_test.reshape((X_test.shape[0], -1))

puissance_config = Puissance()

clf = NEATClassifier(number_of_generations=5,
                     fitness_threshold=0.5,
                     pop_size=5,
                     puissance_config = puissance_config)
# results = {}
# best_fitness = 0

# print("*** Running generation {} ***".format(str(i)))
# with Capturing() as output:
# neat_genome = clf.fit(X_train_fl, y_train.ravel())

#     curr_fitness = find_metric_in_output(output, "Fitness:")
#     curr_popavgfit = find_metric_in_output(output, "Population's average fitness:")
#     curr_stdev = find_metric_in_output(output, "stdev:")

#     print("Fitness: {}".format(curr_fitness))
#     print("Population's average fitness: {}".format(curr_popavgfit))
#     print("Standard deviation: {}".format(curr_stdev))

# print("---")
# if curr_fitness > best_fitness:
#     best_fitness = curr_fitness

# print("Best fitness: {}".format(best_fitness))

# results[i] = {
#     "fitness":curr_fitness,
#     "pop_avg_fitness":curr_popavgfit,
#     "stdev":curr_stdev
# }
    

# print("---\n")

# %%
neat_genome = clf.fit(X_train_fl, y_train.ravel())
        
#     curr_fitness = find_metric_in_output(output, "Fitness:")
#     curr_popavgfit = find_metric_in_output(output, "Population's average fitness:")
#     curr_stdev = find_metric_in_output(output, "stdev:")
        
#     print("Fitness: {}".format(curr_fitness))
#     print("Population's average fitness: {}".format(curr_popavgfit))
#     print("Standard deviation: {}".format(curr_stdev))

#     print("---")
#     if curr_fitness > best_fitness:
#         best_fitness = curr_fitness
        
#     print("Best fitness: {}".format(best_fitness))
    
#     print(find_metric_in_output(output, "Generation time:"))
    
#     results[i] = {
#         "fitness":curr_fitness,
#         "pop_avg_fitness":curr_popavgfit,
#         "stdev":curr_stdev   
#     }

#     print("---\n")
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: 0.10000 stdev: 0.03333
# Best fitness: 0.16667 - size: (10, 30720) - species 1 - id 5
# Currently reproducing
# Average adjusted fitness: 0.017
# Spawns:
#
# [5]
# Mean genetic distance 0.595, standard deviation 0.416
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0     5      0.2    0.017     0
# Total extinctions: 0
# Generation time: 5.577 sec
#
#  ****** Running generation 1 ******
#
# Unique puissance values: {49.45118836390597}
# Unique puissance values: {49.45118836390597}
# Unique puissance values: {49.45118836390597, 50}
# Unique puissance values: {49.958333333333336, 49.45118836390597}
# Unique puissance values: {49.45118836390597, 50.0}
# Population's average fitness: 0.11667 stdev: 0.04082
# Best fitness: 0.16667 - size: (10, 30720) - species 1 - id 5
# Currently reproducing
# Average adjusted fitness: 0.033
# Spawns:
#
# [5]
# Mean genetic distance 0.708, standard deviation 0.289
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1     5      0.2    0.033     1
# Total extinctions: 0
# Generation time: 5.884 sec (5.730 average)
#
#  ****** Running generation 2 ******
#
# Unique puissance values: {48.90237672781194}
# Unique puissance values: {48.90237672781194, 49.409521697239306}
# Unique puissance values: {49.906835937500006, 49.45118836390597, 49.40021924408246, 49.409521697239306}
# Unique puissance values: {48.90237672781194, 49.40021924408246}
# Unique puissance values: {49.93795138888889, 49.45118836390597, 49.43101772986545, 49.409521697239306}
# Population's average fitness: 0.20000 stdev: 0.04082
# Best fitness: 0.25000 - size: (12, 30610) - species 1 - id 9
# Currently reproducing
# Average adjusted fitness: 0.033
# Spawns:
#
# [5]
# Mean genetic distance 0.538, standard deviation 0.129
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2     5      0.2    0.033     0
# Total extinctions: 0
# Generation time: 6.054 sec (5.838 average)
#
#  ****** Running generation 3 ******
#
# Unique puissance values: {48.86071006114528, 49.358024301405976, 48.85140760798843, 48.90237672781194}
# Unique puissance values: {48.85140760798843, 48.35356509171791}
# Unique puissance values: {48.85140760798843, 48.35356509171791, 48.8958258575874}
# Unique puissance values: {48.86071006114528, 49.358024301405976, 48.90237672781194, 49.42938561831686, 49.42007928913786}
# Unique puissance values: {48.86071006114528, 49.90014555905189, 48.85140760798843, 49.39359922906399, 49.40290039021345, 49.358024301405976, 49.444561269843085}
# Population's average fitness: 0.18333 stdev: 0.06236
# Best fitness: 0.25000 - size: (12, 30610) - species 1 - id 9
# Currently reproducing
# Average adjusted fitness: 0.100
# Spawns:
#
# [5]
# Mean genetic distance 0.452, standard deviation 0.215
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3     5      0.2    0.100     1
# Total extinctions: 0
# Generation time: 6.009 sec (5.881 average)
#
#  ****** Running generation 4 ******
#
# Unique puissance values: {48.3025959718944, 47.80475345562388}
# Unique puissance values: {48.80921266531195, 48.35356509171791, 48.31189842505125, 48.3025959718944}
# Unique puissance values: {48.80921266531195, 48.35356509171791, 48.31189842505125, 48.84645455337648, 48.8557560375278}
# Unique puissance values: {48.80921266531195, 48.35356509171791, 48.31189842505125, 48.84645455337648, 48.8557560375278}
# Unique puissance values: {48.3025959718944, 48.32905911163542, 47.80475345562388}
# Population's average fitness: 0.21667 stdev: 0.04082
# Best fitness: 0.25000 - size: (10, 30596) - species 1 - id 10
# Currently reproducing
# Average adjusted fitness: 0.050
# Spawns:
#
# [5]
# Mean genetic distance 0.450, standard deviation 0.198
# Population of 5 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4     5      0.2    0.050     2
# Total extinctions: 0
# Generation time: 5.962 sec (5.897 average)
# Key: 9
# Fitness: 0.25
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=0.47704315593021546, response=1.0, activation=sigmoid, aggregation=sum)
# 	1 DefaultNodeGene(key=1, bias=-0.35459115862093543, response=1.0, activation=sigmoid, aggregation=sum)
# 	2 DefaultNodeGene(key=2, bias=1.9719887424771663, response=1.0, activation=sigmoid, aggregation=sum)
# 	3 DefaultNodeGene(key=3, bias=-0.6073693614777625, response=1.0, activation=sigmoid, aggregation=sum)
# 	4 DefaultNodeGene(key=4, bias=-0.8365703854149315, response=1.0, activation=sigmoid, aggregation=sum)
# 	5 DefaultNodeGene(key=5, bias=-0.15418009048254933, response=1.0, activation=sigmoid, aggregation=sum)
# 	6 DefaultNodeGene(key=6, bias=-2.2588631454160866, response=1.0, activation=sigmoid, aggregation=sum)
# 	7 DefaultNodeGene(key=7, bias=-0.06614084884388594, response=1.0, activation=sigmoid, aggregation=sum)
# 	8 DefaultNodeGene(key=8, bias=-0.016392005633225282, response=1.0, activation=sigmoid, aggregation=sum)
# 	9 DefaultNodeGene(key=9, bias=0.6484467359938565, response=1.0, activation=sigmoid, aggregation=sum)
# 	11 DefaultNodeGene(key=11, bias=-0.6406850081752489, response=1.0, activation=sigmoid, aggregation=sum)
# 	12 DefaultNodeGene(key=12, bias=-1.967096250009824, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-3072, 0), weight=-0.7349604260152831, enabled=True)
# 	DefaultConnectionGene(key=(-3072, 1), weight=0.27085268007325625, enabled=True)
# 	DefaultConnectionGene(key=(-3072, 2), weight=-0.6966266928008958, enabled=True)
# 	DefaultConnectionGene(key=(-3072, 3), weight=-0.8192278452361923, enabled=True)
# 	DefaultConnectionGene(key=(-3072, 4), weight=1.3251175169946763, enabled=True)
# 	DefaultConnectionGene(key=(-3072, 5), weight=-0.06575269889718705, enabled=True)
# 	DefaultConnectionGene(key=(-3072, 6), weight=0.004328605544476347, enabled=True)
# 	DefaultConnectionGene(key=(-3072, 7), weight=-0.36246125470416124, enabled=True)
# 	DefaultConnectionGene(key=(-3072, 8), weight=-0.4295559931525049, enabled=True)
# 	DefaultConnectionGene(key=(-3072, 9), weight=-0.3561517235541135, enabled=True)
# 	DefaultConnectionGene(key=(-3071, 0), weight=-0.13422647664716028, enabled=True)
# 	DefaultConnectionGene(key=(-3071, 1), weight=0.9216901780494702, enabled=True)
# 	DefaultConnectionGene(key=(-3071, 2), weight=0.8968440363208642, enabled=True)
# 	DefaultConnectionGene(key=(-3071, 3), weight=-1.8409433362760375, enabled=True)
# 	DefaultConnectionGene(key=(-3071, 4), weight=0.1643960344536797, enabled=True)
# 	DefaultConnectionGene(key=(-3071, 5), weight=0.4892909375745871, enabled=True)
# 	DefaultConnectionGene(key=(-3071, 6), weight=0.37943031684195283, enabled=True)
# 	DefaultConnectionGene(key=(-3071, 7), weight=1.265696454365186, enabled=True)
# 	DefaultConnectionGene(key=(-3071, 8), weight=0.8626164303828284, enabled=True)
# 	DefaultConnectionGene(key=(-3071, 9), weight=-0.6270127404537146, enabled=True)
# 	DefaultConnectionGene(key=(-3070, 0), weight=1.25644529183795, enabled=True)
# 	DefaultConnectionGene(key=(-3070, 1), weight=0.32582902463576346, enabled=True)
# 	DefaultConnectionGene(key=(-3070, 2), weight=0.14655654513220007, enabled=True)
# 	DefaultConnectionGene(key=(-3070, 3), weight=1.884436461517846, enabled=True)
# 	DefaultConnectionGene(key=(-3070, 4), weight=0.28434489596345996, enabled=True)
# 	DefaultConnectionGene(key=(-3070, 5), weight=-1.1470034336650752, enabled=True)
# 	DefaultConnectionGene(key=(-3070, 6), weight=0.6380416455704142, enabled=True)
# 	DefaultConnectionGene(key=(-3070, 7), weight=-0.9377607884100498, enabled=True)
# 	DefaultConnectionGene(key=(-3070, 8), weight=0.4684923805772167, enabled=True)
# 	DefaultConnectionGene(key=(-3070, 9), weight=0.9446523268166049, enabled=True)
# 	DefaultConnectionGene(key=(-3069, 0), weight=-2.6494652790655175, enabled=True)
# 	DefaultConnectionGene(key=(-3069, 1), weight=0.2473935499190449, enabled=True)
# 	DefaultConnectionGene(key=(-3069, 2), weight=1.006662580553057, enabled=True)
# 	DefaultConnectionGene(key=(-3069, 3), weight=-0.10878422793792542, enabled=True)
# 	DefaultConnectionGene(key=(-3069, 4), weight=-1.9605439590730254, enabled=True)
# 	DefaultConnectionGene(key=(-3069, 5), weight=-0.5531252513091229, enabled=True)
# 	DefaultConnectionGene(key=(-3069, 6), weight=-1.8607411210052711, enabled=True)
# 	DefaultConnectionGene(key=(-3069, 7), weight=-1.4848275444885721, enabled=True)
# 	DefaultConnectionGene(key=(-3069, 8), weight=1.119596825923219, enabled=True)
# 	DefaultConnectionGene(key=(-3069, 9), weight=-0.742884714910237, enabled=True)
# 	DefaultConnectionGene(key=(-3068, 0), weight=0.48473738720576276, enabled=True)
# 	DefaultConnectionGene(key=(-3068, 1), weight=0.145455204527357, enabled=True)
# 	DefaultConnectionGene(key=(-3068, 2), weight=1.245355774219341, enabled=True)
# 	DefaultConnectionGene(key=(-3068, 3), weight=-0.03771912801873454, enabled=True)
# 	DefaultConnectionGene(key=(-3068, 4), weight=0.39017944545111966, enabled=True)
# 	DefaultConnectionGene(key=(-3068, 5), weight=-0.5199738736765691, enabled=True)
# 	DefaultConnectionGene(key=(-3068, 6), weight=0.6412778707325814, enabled=True)
# 	DefaultConnectionGene(key=(-3068, 7), weight=-0.15350216415222745, enabled=True)
# 	DefaultConnectionGene(key=(-3068, 8), weight=-0.6977450348857945, enabled=True)
# 	DefaultConnectionGene(key=(-3068, 9), weight=-0.012421386054324919, enabled=True)
# 	DefaultConnectionGene(key=(-3067, 0), weight=-0.1032105946904291, enabled=True)
# 	DefaultConnectionGene(key=(-3067, 1), weight=0.41997434384485377, enabled=True)
# 	DefaultConnectionGene(key=(-3067, 2), weight=0.6535945092565976, enabled=True)
# 	DefaultConnectionGene(key=(-3067, 3), weight=-0.33930043368735296, enabled=True)
# 	DefaultConnectionGene(key=(-3067, 4), weight=-0.46593652831133164, enabled=True)
# 	DefaultConnectionGene(key=(-3067, 5), weight=2.809651552500036, enabled=True)
# 	DefaultConnectionGene(key=(-3067, 6), weight=-0.6110372610989311, enabled=True)
# 	DefaultConnectionGene(key=(-3067, 7), weight=-0.08648797500246222, enabled=True)
# 	DefaultConnectionGene(key=(-3067, 8), weight=0.5526464452962807, enabled=True)
# 	DefaultConnectionGene(key=(-3067, 9), weight=1.1537607266491394, enabled=True)
# 	DefaultConnectionGene(key=(-3066, 0), weight=-0.03276868015841172, enabled=True)
# 	DefaultConnectionGene(key=(-3066, 1), weight=0.02625483097639243, enabled=True)
# 	DefaultConnectionGene(key=(-3066, 2), weight=-0.610554226236482, enabled=True)
# 	DefaultConnectionGene(key=(-3066, 3), weight=1.1049092049799123, enabled=True)
# 	DefaultConnectionGene(key=(-3066, 4), weight=-0.04614452809656391, enabled=True)
# 	DefaultConnectionGene(key=(-3066, 5), weight=0.4200960397767177, enabled=True)
# 	DefaultConnectionGene(key=(-3066, 6), weight=-0.42372191529106273, enabled=True)
# 	DefaultConnectionGene(key=(-3066, 7), weight=0.3376656740176977, enabled=True)
# 	DefaultConnectionGene(key=(-3066, 8), weight=0.5343118916173155, enabled=True)
# 	DefaultConnectionGene(key=(-3066, 9), weight=-0.7046134986397046, enabled=True)
# 	DefaultConnectionGene(key=(-3065, 0), weight=0.5739676762967698, enabled=True)
# 	DefaultConnectionGene(key=(-3065, 1), weight=-0.7868068264536592, enabled=True)
# 	DefaultConnectionGene(key=(-3065, 2), weight=0.3182923189821318, enabled=True)
# 	DefaultConnectionGene(key=(-3065, 3), weight=1.1644042831425223, enabled=True)
# 	DefaultConnectionGene(key=(-3065, 4), weight=-0.3106797123741159, enabled=True)
# 	DefaultConnectionGene(key=(-3065, 5), weight=-0.42117508708647045, enabled=True)
# 	DefaultConnectionGene(key=(-3065, 6), weight=-0.8880717013220195, enabled=True)
# 	DefaultConnectionGene(key=(-3065, 7), weight=1.571832352289686, enabled=True)
# 	DefaultConnectionGene(key=(-3065, 8), weight=0.22264679167825407, enabled=True)
# 	DefaultConnectionGene(key=(-3065, 9), weight=-0.32138244694446494, enabled=True)
# 	DefaultConnectionGene(key=(-3064, 0), weight=2.2133726523649706, enabled=True)
# 	DefaultConnectionGene(key=(-3064, 1), weight=-0.6033843581889045, enabled=False)
# 	DefaultConnectionGene(key=(-3064, 2), weight=-1.650467134732711, enabled=True)
# 	DefaultConnectionGene(key=(-3064, 3), weight=-0.20651595440244253, enabled=True)
# 	DefaultConnectionGene(key=(-3064, 4), weight=2.6347836173524013, enabled=True)
# 	DefaultConnectionGene(key=(-3064, 5), weight=-1.756978749050853, enabled=True)
# 	DefaultConnectionGene(key=(-3064, 6), weight=0.44037012072900306, enabled=True)
# 	DefaultConnectionGene(key=(-3064, 7), weight=-0.9687784483332764, enabled=True)
# 	DefaultConnectionGene(key=(-3064, 8), weight=-1.9034471037978058, enabled=True)
# 	DefaultConnectionGene(key=(-3064, 9), weight=0.25074285118872297, enabled=True)
# 	DefaultConnectionGene(key=(-3063, 0), weight=0.058534797806233385, enabled=True)
# 	DefaultConnectionGene(key=(-3063, 1), weight=-1.8612368938142416, enabled=True)
# 	DefaultConnectionGene(key=(-3063, 2), weight=0.1813579351853852, enabled=True)
# 	DefaultConnectionGene(key=(-3063, 3), weight=-0.4526121818162875, enabled=True)
# 	DefaultConnectionGene(key=(-3063, 4), weight=-1.4418846555225893, enabled=True)
# 	DefaultConnectionGene(key=(-3063, 5), weight=-0.591266482294718, enabled=True)
# 	DefaultConnectionGene(key=(-3063, 6), weight=-0.37348127422523486, enabled=True)
# 	DefaultConnectionGene(key=(-3063, 7), weight=1.1151369581491832, enabled=True)
# 	DefaultConnectionGene(key=(-3063, 8), weight=-0.805049527011654, enabled=True)
# 	DefaultConnectionGene(key=(-3063, 9), weight=-0.36646351674807115, enabled=True)
# 	DefaultConnectionGene(key=(-3062, 0), weight=0.22398308147865947, enabled=True)
# 	DefaultConnectionGene(key=(-3062, 1), weight=0.5216842263952718, enabled=True)
# 	DefaultConnectionGene(key=(-3062, 2), weight=-0.1697471472420167, enabled=True)
# 	DefaultConnectionGene(key=(-3062, 3), weight=-1.071128272773292, enabled=True)
# 	DefaultConnectionGene(key=(-3062, 4), weight=0.5412009706558891, enabled=True)
# 	DefaultConnectionGene(key=(-3062, 5), weight=2.3148893804877706, enabled=True)
# 	DefaultConnectionGene(key=(-3062, 6), weight=-0.7175389022881222, enabled=True)
# 	DefaultConnectionGene(key=(-3062, 7), weight=0.7873234032509178, enabled=True)
# 	DefaultConnectionGene(key=(-3062, 8), weight=0.0751507822505252, enabled=True)
# 	DefaultConnectionGene(key=(-3062, 9), weight=0.4282747980698349, enabled=True)
# 	DefaultConnectionGene(key=(-3061, 0), weight=1.1701790710159379, enabled=True)
# 	DefaultConnectionGene(key=(-3061, 1), weight=0.2810714051650496, enabled=True)
# 	DefaultConnectionGene(key=(-3061, 2), weight=-0.10359628046119296, enabled=True)
# 	DefaultConnectionGene(key=(-3061, 3), weight=-1.0634944225929153, enabled=True)
# 	DefaultConnectionGene(key=(-3061, 4), weight=-0.14174848205601384, enabled=True)
# 	DefaultConnectionGene(key=(-3061, 5), weight=-0.08579373901954113, enabled=True)
# 	DefaultConnectionGene(key=(-3061, 6), weight=-0.3484100249691183, enabled=True)
# 	DefaultConnectionGene(key=(-3061, 7), weight=-0.22293790943495226, enabled=True)
# 	DefaultConnectionGene(key=(-3061, 8), weight=-0.3698163410595984, enabled=True)
# 	DefaultConnectionGene(key=(-3061, 9), weight=-1.018816637476707, enabled=True)
# 	DefaultConnectionGene(key=(-3060, 0), weight=-0.3726713605108289, enabled=True)
# 	DefaultConnectionGene(key=(-3060, 1), weight=1.7701602443861901, enabled=True)
# 	DefaultConnectionGene(key=(-3060, 2), weight=0.24694263036500225, enabled=True)
# 	DefaultConnectionGene(key=(-3060, 3), weight=-0.13931420750805978, enabled=True)
# 	DefaultConnectionGene(key=(-3060, 4), weight=-0.8275349443278405, enabled=True)
# 	DefaultConnectionGene(key=(-3060, 5), weight=3.217560250200733, enabled=True)
# 	DefaultConnectionGene(key=(-3060, 6), weight=1.151054396494098, enabled=True)
# 	DefaultConnectionGene(key=(-3060, 7), weight=-1.7271857451474608, enabled=True)
# 	DefaultConnectionGene(key=(-3060, 8), weight=-0.1447283821732852, enabled=True)
# 	DefaultConnectionGene(key=(-3060, 9), weight=-0.4688252375968951, enabled=True)
# 	DefaultConnectionGene(key=(-3059, 0), weight=1.724014896479481, enabled=True)
# 	DefaultConnectionGene(key=(-3059, 1), weight=1.155407604051393, enabled=True)
# 	DefaultConnectionGene(key=(-3059, 2), weight=-1.8086596316193169, enabled=True)
# 	DefaultConnectionGene(key=(-3059, 3), weight=-0.5449641240973101, enabled=True)
# 	DefaultConnectionGene(key=(-3059, 4), weight=1.144726453256599, enabled=True)
# 	DefaultConnectionGene(key=(-3059, 5), weight=-1.8260818414002704, enabled=True)
# 	DefaultConnectionGene(key=(-3059, 6), weight=-0.20811877445130175, enabled=True)
# 	DefaultConnectionGene(key=(-3059, 7), weight=1.2827444509743502, enabled=True)
# 	DefaultConnectionGene(key=(-3059, 8), weight=-0.7367239008624111, enabled=True)
# 	DefaultConnectionGene(key=(-3059, 9), weight=1.6125913750501242, enabled=True)
# 	DefaultConnectionGene(key=(-3058, 0), weight=0.14137109092047312, enabled=True)
# 	DefaultConnectionGene(key=(-3058, 1), weight=1.0369207379247125, enabled=True)
# 	DefaultConnectionGene(key=(-3058, 2), weight=-1.551107481204624, enabled=True)
# 	DefaultConnectionGene(key=(-3058, 3), weight=-0.11819280633767464, enabled=False)
# 	DefaultConnectionGene(key=(-3058, 4), weight=-1.909140560016919, enabled=True)
# 	DefaultConnectionGene(key=(-3058, 5), weight=-1.0517554358097356, enabled=True)
# 	DefaultConnectionGene(key=(-3058, 6), weight=0.8259184907075462, enabled=True)
# 	DefaultConnectionGene(key=(-3058, 7), weight=1.3946949995318108, enabled=True)
# 	DefaultConnectionGene(key=(-3058, 8), weight=0.9348213707637172, enabled=True)
# 	DefaultConnectionGene(key=(-3058, 9), weight=-0.3029019814090666, enabled=True)
# 	DefaultConnectionGene(key=(-3057, 0), weight=-0.15482067134633065, enabled=True)
# 	DefaultConnectionGene(key=(-3057, 1), weight=0.6315114593472263, enabled=True)
# 	DefaultConnectionGene(key=(-3057, 2), weight=0.09651247508250582, enabled=True)
# 	DefaultConnectionGene(key=(-3057, 3), weight=-1.1564550063840093, enabled=True)
# 	DefaultConnectionGene(key=(-3057, 4), weight=0.3573050336797263, enabled=True)
# 	DefaultConnectionGene(key=(-3057, 5), weight=-0.6126744926520349, enabled=True)
# 	DefaultConnectionGene(key=(-3057, 6), weight=1.5174650460195611, enabled=True)
# 	DefaultConnectionGene(key=(-3057, 7), weight=1.1882318172854716, enabled=True)
# 	DefaultConnectionGene(key=(-3057, 8), weight=-0.23250422025963216, enabled=True)
# 	DefaultConnectionGene(key=(-3057, 9), weight=2.0594856906206025, enabled=True)
# 	DefaultConnectionGene(key=(-3056, 0), weight=1.858250443561288, enabled=True)
# 	DefaultConnectionGene(key=(-3056, 1), weight=2.2191607845564114, enabled=True)
# 	DefaultConnectionGene(key=(-3056, 2), weight=1.587461667824689, enabled=True)
# 	DefaultConnectionGene(key=(-3056, 3), weight=0.669309578647644, enabled=True)
# 	DefaultConnectionGene(key=(-3056, 4), weight=-1.3692411108925053, enabled=True)
# 	DefaultConnectionGene(key=(-3056, 5), weight=0.938876244189505, enabled=True)
# 	DefaultConnectionGene(key=(-3056, 6), weight=-1.5977987244895577, enabled=True)
# 	DefaultConnectionGene(key=(-3056, 7), weight=-1.2500628047999252, enabled=True)
# 	DefaultConnectionGene(key=(-3056, 8), weight=-0.1481494038630512, enabled=True)
# 	DefaultConnectionGene(key=(-3056, 9), weight=-0.2789782605366228, enabled=True)
# 	DefaultConnectionGene(key=(-3055, 0), weight=0.00030198731361542837, enabled=True)
# 	DefaultConnectionGene(key=(-3055, 1), weight=0.023823278153161993, enabled=True)
# 	DefaultConnectionGene(key=(-3055, 2), weight=-0.5147733828246778, enabled=True)
# 	DefaultConnectionGene(key=(-3055, 3), weight=-0.45876301441799977, enabled=True)
# 	DefaultConnectionGene(key=(-3055, 4), weight=1.4219153876523296, enabled=True)
# 	DefaultConnectionGene(key=(-3055, 5), weight=-0.061150456083365, enabled=True)
# 	DefaultConnectionGene(key=(-3055, 6), weight=0.31309039264471217, enabled=True)
# 	DefaultConnectionGene(key=(-3055, 7), weight=0.21699531826516438, enabled=True)
# 	DefaultConnectionGene(key=(-3055, 8), weight=0.495415593240284, enabled=True)
# 	DefaultConnectionGene(key=(-3055, 9), weight=-1.3754876645137517, enabled=True)
# 	DefaultConnectionGene(key=(-3054, 0), weight=-1.2404340512591576, enabled=True)
# 	DefaultConnectionGene(key=(-3054, 1), weight=0.5388298970781517, enabled=True)
# 	DefaultConnectionGene(key=(-3054, 2), weight=0.3314197407557451, enabled=True)
# 	DefaultConnectionGene(key=(-3054, 3), weight=-2.309890461601348, enabled=True)
# 	DefaultConnectionGene(key=(-3054, 4), weight=-0.8394819715989493, enabled=True)
# 	DefaultConnectionGene(key=(-3054, 5), weight=-0.5755312098325954, enabled=True)
# 	DefaultConnectionGene(key=(-3054, 6), weight=-0.6510255762526168, enabled=True)
# 	DefaultConnectionGene(key=(-3054, 7), weight=0.8799388731226243, enabled=True)
# 	DefaultConnectionGene(key=(-3054, 8), weight=0.037296752253230814, enabled=True)
# 	DefaultConnectionGene(key=(-3054, 9), weight=-0.3278074400620877, enabled=True)
# 	DefaultConnectionGene(key=(-3053, 0), weight=0.17080738151653008, enabled=True)
# 	DefaultConnectionGene(key=(-3053, 1), weight=-0.9554297287610465, enabled=True)
# 	DefaultConnectionGene(key=(-3053, 2), weight=0.6417372794917348, enabled=True)
# 	DefaultConnectionGene(key=(-3053, 3), weight=-1.5425341874970249, enabled=True)
# 	DefaultConnectionGene(key=(-3053, 4), weight=-1.7626042614165203, enabled=True)
# 	DefaultConnectionGene(key=(-3053, 5), weight=0.7054100153108087, enabled=True)
# 	DefaultConnectionGene(key=(-3053, 6), weight=-0.1937386976184972, enabled=True)
# 	DefaultConnectionGene(key=(-3053, 7), weight=-0.7578878909645739, enabled=True)
# 	DefaultConnectionGene(key=(-3053, 8), weight=-0.7959889730357159, enabled=True)
# 	DefaultConnectionGene(key=(-3053, 9), weight=-0.3966569927086138, enabled=True)
# 	DefaultConnectionGene(key=(-3052, 0), weight=0.19864573505422972, enabled=True)
# 	DefaultConnectionGene(key=(-3052, 1), weight=-0.09093616513129757, enabled=True)
# 	DefaultConnectionGene(key=(-3052, 2), weight=-1.0154644488545372, enabled=True)
# 	DefaultConnectionGene(key=(-3052, 3), weight=-1.2970821261206362, enabled=True)
# 	DefaultConnectionGene(key=(-3052, 4), weight=0.3912670025750472, enabled=True)
# 	DefaultConnectionGene(key=(-3052, 5), weight=1.6898419351345084, enabled=True)
# 	DefaultConnectionGene(key=(-3052, 6), weight=0.15672929599652785, enabled=True)
# 	DefaultConnectionGene(key=(-3052, 7), weight=-0.49024708812857776, enabled=True)
# 	DefaultConnectionGene(key=(-3052, 8), weight=-0.45506896779677897, enabled=True)
# 	DefaultConnectionGene(key=(-3052, 9), weight=0.14434947693435568, enabled=True)
# 	DefaultConnectionGene(key=(-3051, 0), weight=1.198272362640821, enabled=True)
# 	DefaultConnectionGene(key=(-3051, 1), weight=0.9080682943545735, enabled=True)
# 	DefaultConnectionGene(key=(-3051, 2), weight=-0.8540524763022548, enabled=True)
# 	DefaultConnectionGene(key=(-3051, 3), weight=1.2989360066305309, enabled=True)
# 	DefaultConnectionGene(key=(-3051, 4), weight=2.6563030979751434, enabled=True)
# 	DefaultConnectionGene(key=(-3051, 5), weight=1.1142314590945734, enabled=True)
# 	DefaultConnectionGene(key=(-3051, 6), weight=0.9050124312737156, enabled=True)
# 	DefaultConnectionGene(key=(-3051, 7), weight=-1.824795664305809, enabled=True)
# 	DefaultConnectionGene(key=(-3051, 8), weight=-0.0613392825275213, enabled=True)
# 	DefaultConnectionGene(key=(-3051, 9), weight=0.929848776310178, enabled=True)
# 	DefaultConnectionGene(key=(-3050, 0), weight=0.011954220799461106, enabled=True)
# 	DefaultConnectionGene(key=(-3050, 1), weight=-0.05211162365188919, enabled=True)
# 	DefaultConnectionGene(key=(-3050, 2), weight=0.3263412208164358, enabled=True)
# 	DefaultConnectionGene(key=(-3050, 3), weight=-0.6904820737404448, enabled=True)
# 	DefaultConnectionGene(key=(-3050, 4), weight=-0.8418006083917253, enabled=True)
# 	DefaultConnectionGene(key=(-3050, 5), weight=0.6726070347699875, enabled=True)
# 	DefaultConnectionGene(key=(-3050, 6), weight=1.080731398213506, enabled=True)
# 	DefaultConnectionGene(key=(-3050, 7), weight=2.0614415097721768, enabled=True)
# 	DefaultConnectionGene(key=(-3050, 8), weight=0.3720751996841828, enabled=True)
# 	DefaultConnectionGene(key=(-3050, 9), weight=2.9298245178708386, enabled=True)
# 	DefaultConnectionGene(key=(-3049, 0), weight=-1.3440863992621193, enabled=True)
# 	DefaultConnectionGene(key=(-3049, 1), weight=0.5137788927792443, enabled=True)
# 	DefaultConnectionGene(key=(-3049, 2), weight=-1.4368613041029457, enabled=True)
# 	DefaultConnectionGene(key=(-3049, 3), weight=-0.25804600754846657, enabled=True)
# 	DefaultConnectionGene(key=(-3049, 4), weight=-0.09070967040745903, enabled=True)
# 	DefaultConnectionGene(key=(-3049, 5), weight=0.0007843853496714015, enabled=True)
# 	DefaultConnectionGene(key=(-3049, 6), weight=-1.0973810902814867, enabled=True)
# 	DefaultConnectionGene(key=(-3049, 7), weight=-0.679703113154712, enabled=True)
# 	DefaultConnectionGene(key=(-3049, 8), weight=0.1939163727298452, enabled=True)
# 	DefaultConnectionGene(key=(-3049, 9), weight=0.002224261212219582, enabled=True)
# 	DefaultConnectionGene(key=(-3048, 0), weight=1.7168999142749244, enabled=True)
# 	DefaultConnectionGene(key=(-3048, 1), weight=-0.3672182068460901, enabled=True)
# 	DefaultConnectionGene(key=(-3048, 2), weight=1.7973339635474725, enabled=True)
# 	DefaultConnectionGene(key=(-3048, 3), weight=0.6845545893463406, enabled=True)
# 	DefaultConnectionGene(key=(-3048, 4), weight=-0.10160104693755194, enabled=True)
# 	DefaultConnectionGene(key=(-3048, 5), weight=-0.4796498266231304, enabled=True)
# 	DefaultConnectionGene(key=(-3048, 6), weight=0.3009174702512286, enabled=True)
# 	DefaultConnectionGene(key=(-3048, 7), weight=0.34299045364796454, enabled=True)
# 	DefaultConnectionGene(key=(-3048, 8), weight=0.7751959413760708, enabled=True)
# 	DefaultConnectionGene(key=(-3048, 9), weight=0.47932190508721345, enabled=True)
# 	DefaultConnectionGene(key=(-3047, 0), weight=-0.3783836467558672, enabled=True)
# 	DefaultConnectionGene(key=(-3047, 1), weight=-1.9326111919167859, enabled=True)
# 	DefaultConnectionGene(key=(-3047, 2), weight=0.9028050129117187, enabled=True)
# 	DefaultConnectionGene(key=(-3047, 3), weight=1.6494750397548175, enabled=True)
# 	DefaultConnectionGene(key=(-3047, 4), weight=-1.8180773512358663, enabled=True)
# 	DefaultConnectionGene(key=(-3047, 5), weight=-0.5752567607419006, enabled=True)
# 	DefaultConnectionGene(key=(-3047, 6), weight=-0.8558218293238326, enabled=True)
# 	DefaultConnectionGene(key=(-3047, 7), weight=1.2181919375836634, enabled=True)
# 	DefaultConnectionGene(key=(-3047, 8), weight=-1.1061445975395223, enabled=True)
# 	DefaultConnectionGene(key=(-3047, 9), weight=-1.7599172815540554, enabled=True)
# 	DefaultConnectionGene(key=(-3046, 0), weight=1.3745060023902085, enabled=True)
# 	DefaultConnectionGene(key=(-3046, 1), weight=-1.0063888450227247, enabled=True)
# 	DefaultConnectionGene(key=(-3046, 2), weight=1.6415732509701653, enabled=True)
# 	DefaultConnectionGene(key=(-3046, 3), weight=0.40976700722349, enabled=True)
# 	DefaultConnectionGene(key=(-3046, 4), weight=-0.906450512010267, enabled=True)
# 	DefaultConnectionGene(key=(-3046, 5), weight=-0.21840823742372656, enabled=True)
# 	DefaultConnectionGene(key=(-3046, 6), weight=0.3586610746215429, enabled=True)
# 	DefaultConnectionGene(key=(-3046, 7), weight=-3.6164900281884416, enabled=True)
# 	DefaultConnectionGene(key=(-3046, 8), weight=0.5633079665136598, enabled=True)
# 	DefaultConnectionGene(key=(-3046, 9), weight=-0.6724081657060486, enabled=True)
# 	DefaultConnectionGene(key=(-3045, 0), weight=-1.0529109283738742, enabled=True)
# 	DefaultConnectionGene(key=(-3045, 1), weight=-0.7070842294354072, enabled=True)
# 	DefaultConnectionGene(key=(-3045, 2), weight=0.9529903180809032, enabled=True)
# 	DefaultConnectionGene(key=(-3045, 3), weight=-0.31735513872765525, enabled=True)
# 	DefaultConnectionGene(key=(-3045, 4), weight=1.4581508716866154, enabled=True)
# 	DefaultConnectionGene(key=(-3045, 5), weight=-0.45722909820915336, enabled=True)
# 	DefaultConnectionGene(key=(-3045, 6), weight=-0.24992427745390688, enabled=True)
# 	DefaultConnectionGene(key=(-3045, 7), weight=0.5884860778183584, enabled=True)
# 	DefaultConnectionGene(key=(-3045, 8), weight=-2.1570864972009676, enabled=True)
# 	DefaultConnectionGene(key=(-3045, 9), weight=0.7542566300450445, enabled=True)
# 	DefaultConnectionGene(key=(-3044, 0), weight=1.097675214937342, enabled=True)
# 	DefaultConnectionGene(key=(-3044, 1), weight=-0.9515487085740236, enabled=True)
# 	DefaultConnectionGene(key=(-3044, 2), weight=-0.9257380209202177, enabled=True)
# 	DefaultConnectionGene(key=(-3044, 3), weight=-1.976137818882072, enabled=True)
# 	DefaultConnectionGene(key=(-3044, 4), weight=0.2667616476917785, enabled=True)
# 	DefaultConnectionGene(key=(-3044, 5), weight=-0.37136762961492253, enabled=True)
# 	DefaultConnectionGene(key=(-3044, 6), weight=0.2210483568244166, enabled=True)
# 	DefaultConnectionGene(key=(-3044, 7), weight=1.6909326244999046, enabled=True)
# 	DefaultConnectionGene(key=(-3044, 8), weight=-0.3503983017834991, enabled=True)
# 	DefaultConnectionGene(key=(-3044, 9), weight=0.9614829488378356, enabled=True)
# 	DefaultConnectionGene(key=(-3043, 0), weight=-1.5332071509906675, enabled=True)
# 	DefaultConnectionGene(key=(-3043, 1), weight=0.43588337282665146, enabled=True)
# 	DefaultConnectionGene(key=(-3043, 2), weight=1.4785412236122462, enabled=True)
# 	DefaultConnectionGene(key=(-3043, 3), weight=1.6229974171140695, enabled=True)
# 	DefaultConnectionGene(key=(-3043, 4), weight=1.0418695433886531, enabled=True)
# 	DefaultConnectionGene(key=(-3043, 5), weight=0.6145705365843502, enabled=True)
# 	DefaultConnectionGene(key=(-3043, 6), weight=-2.5875948179271355, enabled=True)
# 	DefaultConnectionGene(key=(-3043, 7), weight=1.1863257307390067, enabled=True)
# 	DefaultConnectionGene(key=(-3043, 8), weight=0.31922618564889427, enabled=True)
# 	DefaultConnectionGene(key=(-3043, 9), weight=-2.006283666903581, enabled=True)
# 	DefaultConnectionGene(key=(-3042, 0), weight=-0.634667785553328, enabled=True)
# 	DefaultConnectionGene(key=(-3042, 1), weight=0.009404921457713012, enabled=True)
# 	DefaultConnectionGene(key=(-3042, 2), weight=0.9785734972336145, enabled=True)
# 	DefaultConnectionGene(key=(-3042, 3), weight=0.8409723009061971, enabled=True)
# 	DefaultConnectionGene(key=(-3042, 4), weight=-0.7516664585109788, enabled=True)
# 	DefaultConnectionGene(key=(-3042, 5), weight=-1.3122865998980502, enabled=True)
# 	DefaultConnectionGene(key=(-3042, 6), weight=0.6075028755039181, enabled=True)
# 	DefaultConnectionGene(key=(-3042, 7), weight=0.22322063237338852, enabled=True)
# 	DefaultConnectionGene(key=(-3042, 8), weight=0.702519190438671, enabled=True)
# 	DefaultConnectionGene(key=(-3042, 9), weight=-0.38149070674437163, enabled=True)
# 	DefaultConnectionGene(key=(-3041, 0), weight=1.065501698665062, enabled=True)
# 	DefaultConnectionGene(key=(-3041, 1), weight=-0.8585067329828491, enabled=True)
# 	DefaultConnectionGene(key=(-3041, 2), weight=-0.4313328526554059, enabled=True)
# 	DefaultConnectionGene(key=(-3041, 3), weight=0.8963835599305473, enabled=True)
# 	DefaultConnectionGene(key=(-3041, 4), weight=-2.5303674684402986, enabled=True)
# 	DefaultConnectionGene(key=(-3041, 5), weight=-0.8313925071836523, enabled=True)
# 	DefaultConnectionGene(key=(-3041, 6), weight=1.163861094440224, enabled=True)
# 	DefaultConnectionGene(key=(-3041, 7), weight=0.6073023038223762, enabled=True)
# 	DefaultConnectionGene(key=(-3041, 8), weight=-0.3089710407211569, enabled=True)
# 	DefaultConnectionGene(key=(-3041, 9), weight=-0.21129053918223736, enabled=True)
# 	DefaultConnectionGene(key=(-3040, 0), weight=1.156320071051078, enabled=True)
# 	DefaultConnectionGene(key=(-3040, 1), weight=0.920587519317094, enabled=True)
# 	DefaultConnectionGene(key=(-3040, 2), weight=-1.0514266541375443, enabled=True)
# 	DefaultConnectionGene(key=(-3040, 3), weight=0.595038989519813, enabled=True)
# 	DefaultConnectionGene(key=(-3040, 4), weight=-0.40013300391314516, enabled=True)
# 	DefaultConnectionGene(key=(-3040, 5), weight=1.6319584654680048, enabled=True)
# 	DefaultConnectionGene(key=(-3040, 6), weight=-0.38256842041364236, enabled=True)
# 	DefaultConnectionGene(key=(-3040, 7), weight=-0.15172416484731321, enabled=True)
# 	DefaultConnectionGene(key=(-3040, 8), weight=0.5867495074003071, enabled=True)
# 	DefaultConnectionGene(key=(-3040, 9), weight=-0.516621143787353, enabled=True)
# 	DefaultConnectionGene(key=(-3039, 0), weight=-1.1048228639249271, enabled=True)
# 	DefaultConnectionGene(key=(-3039, 1), weight=0.16124792135691046, enabled=True)
# 	DefaultConnectionGene(key=(-3039, 2), weight=0.022303079341703225, enabled=True)
# 	DefaultConnectionGene(key=(-3039, 3), weight=0.09149172658146354, enabled=True)
# 	DefaultConnectionGene(key=(-3039, 4), weight=0.22483035216720224, enabled=True)
# 	DefaultConnectionGene(key=(-3039, 5), weight=0.43319624804089196, enabled=True)
# 	DefaultConnectionGene(key=(-3039, 6), weight=1.3946366330905489, enabled=True)
# 	DefaultConnectionGene(key=(-3039, 7), weight=-1.2413857210252162, enabled=True)
# 	DefaultConnectionGene(key=(-3039, 8), weight=0.16672765887573926, enabled=True)
# 	DefaultConnectionGene(key=(-3039, 9), weight=-0.30590304917862754, enabled=True)
# 	DefaultConnectionGene(key=(-3038, 0), weight=0.45199712867697, enabled=True)
# 	DefaultConnectionGene(key=(-3038, 1), weight=-1.647377891500992, enabled=True)
# 	DefaultConnectionGene(key=(-3038, 2), weight=-0.737534896413442, enabled=True)
# 	DefaultConnectionGene(key=(-3038, 3), weight=3.0582061057166627, enabled=True)
# 	DefaultConnectionGene(key=(-3038, 4), weight=-0.9190345532921438, enabled=True)
# 	DefaultConnectionGene(key=(-3038, 5), weight=0.3259444930475332, enabled=True)
# 	DefaultConnectionGene(key=(-3038, 6), weight=-0.5816572360282404, enabled=True)
# 	DefaultConnectionGene(key=(-3038, 7), weight=-0.28652361723649594, enabled=True)
# 	DefaultConnectionGene(key=(-3038, 8), weight=-1.4118025997206192, enabled=True)
# 	DefaultConnectionGene(key=(-3038, 9), weight=-0.1382533937502235, enabled=True)
# 	DefaultConnectionGene(key=(-3037, 0), weight=-0.42178409722488674, enabled=True)
# 	DefaultConnectionGene(key=(-3037, 1), weight=-0.8447121081194786, enabled=True)
# 	DefaultConnectionGene(key=(-3037, 2), weight=0.07944330316125352, enabled=True)
# 	DefaultConnectionGene(key=(-3037, 3), weight=0.27053314154712976, enabled=True)
# 	DefaultConnectionGene(key=(-3037, 4), weight=-1.60713255429212, enabled=True)
# 	DefaultConnectionGene(key=(-3037, 5), weight=-0.740582847490163, enabled=True)
# 	DefaultConnectionGene(key=(-3037, 6), weight=-0.094656741822676, enabled=True)
# 	DefaultConnectionGene(key=(-3037, 7), weight=-0.6982418012803755, enabled=True)
# 	DefaultConnectionGene(key=(-3037, 8), weight=-1.3930584328760618, enabled=True)
# 	DefaultConnectionGene(key=(-3037, 9), weight=0.42905423125078274, enabled=True)
# 	DefaultConnectionGene(key=(-3036, 0), weight=-0.985597445260916, enabled=True)
# 	DefaultConnectionGene(key=(-3036, 1), weight=0.7828270308076827, enabled=True)
# 	DefaultConnectionGene(key=(-3036, 2), weight=0.9215109822808653, enabled=True)
# 	DefaultConnectionGene(key=(-3036, 3), weight=0.255683958518244, enabled=True)
# 	DefaultConnectionGene(key=(-3036, 4), weight=0.3593343279139841, enabled=True)
# 	DefaultConnectionGene(key=(-3036, 5), weight=-0.2143316415083107, enabled=True)
# 	DefaultConnectionGene(key=(-3036, 6), weight=-1.1512348354538524, enabled=True)
# 	DefaultConnectionGene(key=(-3036, 7), weight=0.5543132798821537, enabled=True)
# 	DefaultConnectionGene(key=(-3036, 8), weight=-1.17438951749605, enabled=True)
# 	DefaultConnectionGene(key=(-3036, 9), weight=0.9671369153040124, enabled=True)
# 	DefaultConnectionGene(key=(-3035, 0), weight=0.3865991817931647, enabled=True)
# 	DefaultConnectionGene(key=(-3035, 1), weight=-1.2055024765399887, enabled=True)
# 	DefaultConnectionGene(key=(-3035, 2), weight=1.7461023913754077, enabled=True)
# 	DefaultConnectionGene(key=(-3035, 3), weight=-0.06808934636747953, enabled=True)
# 	DefaultConnectionGene(key=(-3035, 4), weight=3.805935358163002, enabled=True)
# 	DefaultConnectionGene(key=(-3035, 5), weight=-0.8201321924050707, enabled=True)
# 	DefaultConnectionGene(key=(-3035, 6), weight=-0.44603438097088793, enabled=True)
# 	DefaultConnectionGene(key=(-3035, 7), weight=-0.2627607531926982, enabled=True)
# 	DefaultConnectionGene(key=(-3035, 8), weight=-2.9457243300644627, enabled=True)
# 	DefaultConnectionGene(key=(-3035, 9), weight=1.948881729119221, enabled=True)
# 	DefaultConnectionGene(key=(-3034, 0), weight=0.03632511145784244, enabled=True)
# 	DefaultConnectionGene(key=(-3034, 1), weight=0.6688734174686425, enabled=True)
# 	DefaultConnectionGene(key=(-3034, 2), weight=0.18245157411502078, enabled=True)
# 	DefaultConnectionGene(key=(-3034, 3), weight=-1.7562380230212367, enabled=True)
# 	DefaultConnectionGene(key=(-3034, 4), weight=-0.24510028071945356, enabled=True)
# 	DefaultConnectionGene(key=(-3034, 5), weight=-1.0291417772915867, enabled=True)
# 	DefaultConnectionGene(key=(-3034, 6), weight=0.47205198864405873, enabled=True)
# 	DefaultConnectionGene(key=(-3034, 7), weight=0.09471468670420359, enabled=True)
# 	DefaultConnectionGene(key=(-3034, 8), weight=-0.1790001448906999, enabled=True)
# 	DefaultConnectionGene(key=(-3034, 9), weight=3.0514316490204143, enabled=True)
# 	DefaultConnectionGene(key=(-3033, 0), weight=-0.6808611430445882, enabled=True)
# 	DefaultConnectionGene(key=(-3033, 1), weight=-1.4475833068193087, enabled=True)
# 	DefaultConnectionGene(key=(-3033, 2), weight=0.5021317627579549, enabled=True)
# 	DefaultConnectionGene(key=(-3033, 3), weight=-1.0290144780406985, enabled=True)
# 	DefaultConnectionGene(key=(-3033, 4), weight=-1.1898556832252192, enabled=True)
# 	DefaultConnectionGene(key=(-3033, 5), weight=-0.18364763062878975, enabled=True)
# 	DefaultConnectionGene(key=(-3033, 6), weight=1.3427223712713872, enabled=True)
# 	DefaultConnectionGene(key=(-3033, 7), weight=-0.49677064398520765, enabled=True)
# 	DefaultConnectionGene(key=(-3033, 8), weight=-0.620107344733642, enabled=True)
# 	DefaultConnectionGene(key=(-3033, 9), weight=-0.18143239772381542, enabled=True)
# 	DefaultConnectionGene(key=(-3032, 0), weight=-0.4450196156286761, enabled=True)
# 	DefaultConnectionGene(key=(-3032, 1), weight=1.330479175308791, enabled=True)
# 	DefaultConnectionGene(key=(-3032, 2), weight=0.2705017813793214, enabled=True)
# 	DefaultConnectionGene(key=(-3032, 3), weight=-0.204245932918496, enabled=True)
# 	DefaultConnectionGene(key=(-3032, 4), weight=-1.5132145790501152, enabled=True)
# 	DefaultConnectionGene(key=(-3032, 5), weight=0.3519574076710297, enabled=True)
# 	DefaultConnectionGene(key=(-3032, 6), weight=-0.3328397465496924, enabled=True)
# 	DefaultConnectionGene(key=(-3032, 7), weight=-1.9089749779716023, enabled=True)
# 	DefaultConnectionGene(key=(-3032, 8), weight=-0.21005289355263487, enabled=True)
# 	DefaultConnectionGene(key=(-3032, 9), weight=-0.23941815684357232, enabled=True)
# 	DefaultConnectionGene(key=(-3031, 0), weight=-1.160989545697137, enabled=True)
# 	DefaultConnectionGene(key=(-3031, 1), weight=-1.664079270735566, enabled=True)
# 	DefaultConnectionGene(key=(-3031, 2), weight=1.8891072413552021, enabled=True)
# 	DefaultConnectionGene(key=(-3031, 3), weight=-0.4365078081839281, enabled=True)
# 	DefaultConnectionGene(key=(-3031, 4), weight=0.8812892708350234, enabled=True)
# 	DefaultConnectionGene(key=(-3031, 5), weight=0.4912566449150782, enabled=True)
# 	DefaultConnectionGene(key=(-3031, 6), weight=-0.37657684646265505, enabled=True)
# 	DefaultConnectionGene(key=(-3031, 7), weight=0.9208747289864586, enabled=True)
# 	DefaultConnectionGene(key=(-3031, 8), weight=1.3289808758639432, enabled=True)
# 	DefaultConnectionGene(key=(-3031, 9), weight=2.517352504232174, enabled=True)
# 	DefaultConnectionGene(key=(-3030, 0), weight=-0.9631035195410216, enabled=True)
# 	DefaultConnectionGene(key=(-3030, 1), weight=-0.2935002221609919, enabled=True)
# 	DefaultConnectionGene(key=(-3030, 2), weight=-0.7552072400320219, enabled=True)
# 	DefaultConnectionGene(key=(-3030, 3), weight=-1.3485562865424028, enabled=True)
# 	DefaultConnectionGene(key=(-3030, 4), weight=0.5150516931508903, enabled=True)
# 	DefaultConnectionGene(key=(-3030, 5), weight=-0.9782068019302547, enabled=True)
# 	DefaultConnectionGene(key=(-3030, 6), weight=1.2021296006252322, enabled=True)
# 	DefaultConnectionGene(key=(-3030, 7), weight=0.002659353466808456, enabled=True)
# 	DefaultConnectionGene(key=(-3030, 8), weight=0.5420556672014654, enabled=True)
# 	DefaultConnectionGene(key=(-3030, 9), weight=0.17395941067213566, enabled=True)
# 	DefaultConnectionGene(key=(-3029, 0), weight=0.63578743524896, enabled=True)
# 	DefaultConnectionGene(key=(-3029, 1), weight=-0.5199266959738567, enabled=True)
# 	DefaultConnectionGene(key=(-3029, 2), weight=-0.2945037791168855, enabled=True)
# 	DefaultConnectionGene(key=(-3029, 3), weight=-0.6217927678611035, enabled=True)
# 	DefaultConnectionGene(key=(-3029, 4), weight=-1.531611996257906, enabled=True)
# 	DefaultConnectionGene(key=(-3029, 5), weight=-0.9315755007279485, enabled=True)
# 	DefaultConnectionGene(key=(-3029, 6), weight=0.1856322474344717, enabled=True)
# 	DefaultConnectionGene(key=(-3029, 7), weight=-1.0776053257031744, enabled=True)
# 	DefaultConnectionGene(key=(-3029, 8), weight=-1.8981306600169452, enabled=True)
# 	DefaultConnectionGene(key=(-3029, 9), weight=0.46994154218630513, enabled=True)
# 	DefaultConnectionGene(key=(-3028, 0), weight=0.7508686403024233, enabled=True)
# 	DefaultConnectionGene(key=(-3028, 1), weight=0.8934694349114464, enabled=True)
# 	DefaultConnectionGene(key=(-3028, 2), weight=1.468593272696174, enabled=True)
# 	DefaultConnectionGene(key=(-3028, 3), weight=-0.9769668137212695, enabled=True)
# 	DefaultConnectionGene(key=(-3028, 4), weight=1.3729390023779349, enabled=True)
# 	DefaultConnectionGene(key=(-3028, 5), weight=-1.1721421995442354, enabled=True)
# 	DefaultConnectionGene(key=(-3028, 6), weight=1.2783984505527837, enabled=True)
# 	DefaultConnectionGene(key=(-3028, 7), weight=1.1854496242417656, enabled=True)
# 	DefaultConnectionGene(key=(-3028, 8), weight=-0.43064659244449255, enabled=True)
# 	DefaultConnectionGene(key=(-3028, 9), weight=-0.8013621743245368, enabled=True)
# 	DefaultConnectionGene(key=(-3027, 0), weight=-0.250818125277028, enabled=True)
# 	DefaultConnectionGene(key=(-3027, 1), weight=0.21378335939293316, enabled=True)
# 	DefaultConnectionGene(key=(-3027, 2), weight=0.19663843868520947, enabled=True)
# 	DefaultConnectionGene(key=(-3027, 3), weight=0.3991147848608154, enabled=True)
# 	DefaultConnectionGene(key=(-3027, 4), weight=0.45838191457648775, enabled=True)
# 	DefaultConnectionGene(key=(-3027, 5), weight=0.14679199165926526, enabled=True)
# 	DefaultConnectionGene(key=(-3027, 6), weight=1.375416624815613, enabled=True)
# 	DefaultConnectionGene(key=(-3027, 7), weight=1.0004084044839083, enabled=True)
# 	DefaultConnectionGene(key=(-3027, 8), weight=-0.33349968542577835, enabled=True)
# 	DefaultConnectionGene(key=(-3027, 9), weight=-0.23190868522450536, enabled=True)
# 	DefaultConnectionGene(key=(-3026, 0), weight=0.32048069466651, enabled=True)
# 	DefaultConnectionGene(key=(-3026, 1), weight=-1.0801648987945884, enabled=True)
# 	DefaultConnectionGene(key=(-3026, 2), weight=0.5110207103997849, enabled=True)
# 	DefaultConnectionGene(key=(-3026, 3), weight=0.6633496489175796, enabled=True)
# 	DefaultConnectionGene(key=(-3026, 4), weight=-0.6292648193353267, enabled=True)
# 	DefaultConnectionGene(key=(-3026, 5), weight=-0.0010461991120530034, enabled=True)
# 	DefaultConnectionGene(key=(-3026, 6), weight=0.9636640079283307, enabled=True)
# 	DefaultConnectionGene(key=(-3026, 7), weight=0.7215805986994643, enabled=True)
# 	DefaultConnectionGene(key=(-3026, 8), weight=-0.9854872198136724, enabled=True)
# 	DefaultConnectionGene(key=(-3026, 9), weight=-0.8594889595294537, enabled=True)
# 	DefaultConnectionGene(key=(-3025, 0), weight=-0.5090476827470599, enabled=True)
# 	DefaultConnectionGene(key=(-3025, 1), weight=2.6932394592215125, enabled=True)
# 	DefaultConnectionGene(key=(-3025, 2), weight=0.2440607812095673, enabled=True)
# 	DefaultConnectionGene(key=(-3025, 3), weight=0.330967178092325, enabled=True)
# 	DefaultConnectionGene(key=(-3025, 4), weight=-0.05635301555124128, enabled=True)
# 	DefaultConnectionGene(key=(-3025, 5), weight=-0.23251983125650608, enabled=True)
# 	DefaultConnectionGene(key=(-3025, 6), weight=-1.3432531943131836, enabled=True)
# 	DefaultConnectionGene(key=(-3025, 7), weight=-0.13645574358044574, enabled=True)
# 	DefaultConnectionGene(key=(-3025, 8), weight=-0.25069133602763227, enabled=True)
# 	DefaultConnectionGene(key=(-3025, 9), weight=0.4283401772944982, enabled=True)
# 	DefaultConnectionGene(key=(-3024, 0), weight=1.1585081328144877, enabled=True)
# 	DefaultConnectionGene(key=(-3024, 1), weight=-0.8843962907277341, enabled=True)
# 	DefaultConnectionGene(key=(-3024, 2), weight=4.052227006054144, enabled=True)
# 	DefaultConnectionGene(key=(-3024, 3), weight=-0.52088757351984, enabled=True)
# 	DefaultConnectionGene(key=(-3024, 4), weight=0.32209486828411316, enabled=True)
# 	DefaultConnectionGene(key=(-3024, 5), weight=-1.2192340591759294, enabled=True)
# 	DefaultConnectionGene(key=(-3024, 6), weight=1.100198250964799, enabled=True)
# 	DefaultConnectionGene(key=(-3024, 7), weight=1.1972307489684326, enabled=True)
# 	DefaultConnectionGene(key=(-3024, 8), weight=0.024523335427104394, enabled=True)
# 	DefaultConnectionGene(key=(-3024, 9), weight=-1.551788133301417, enabled=True)
# 	DefaultConnectionGene(key=(-3023, 0), weight=-0.6246748403816295, enabled=True)
# 	DefaultConnectionGene(key=(-3023, 1), weight=-0.5332178696481883, enabled=True)
# 	DefaultConnectionGene(key=(-3023, 2), weight=0.23284471458849954, enabled=True)
# 	DefaultConnectionGene(key=(-3023, 3), weight=0.4135841662610544, enabled=True)
# 	DefaultConnectionGene(key=(-3023, 4), weight=1.6646236413655338, enabled=True)
# 	DefaultConnectionGene(key=(-3023, 5), weight=0.023142025443160574, enabled=True)
# 	DefaultConnectionGene(key=(-3023, 6), weight=-0.3166132377755281, enabled=True)
# 	DefaultConnectionGene(key=(-3023, 7), weight=-0.7942869250244897, enabled=True)
# 	DefaultConnectionGene(key=(-3023, 8), weight=2.629905617279027, enabled=True)
# 	DefaultConnectionGene(key=(-3023, 9), weight=-1.1527148322055178, enabled=True)
# 	DefaultConnectionGene(key=(-3022, 0), weight=2.6838546639085212, enabled=True)
# 	DefaultConnectionGene(key=(-3022, 1), weight=0.7083917224925956, enabled=True)
# 	DefaultConnectionGene(key=(-3022, 2), weight=-0.8075007453547828, enabled=True)
# 	DefaultConnectionGene(key=(-3022, 3), weight=0.7646011827172872, enabled=True)
# 	DefaultConnectionGene(key=(-3022, 4), weight=0.19490702236068905, enabled=True)
# 	DefaultConnectionGene(key=(-3022, 5), weight=1.2511846877209936, enabled=True)
# 	DefaultConnectionGene(key=(-3022, 6), weight=1.1424234541360458, enabled=True)
# 	DefaultConnectionGene(key=(-3022, 7), weight=-0.19980947308664435, enabled=True)
# 	DefaultConnectionGene(key=(-3022, 8), weight=0.45929729837396305, enabled=True)
# 	DefaultConnectionGene(key=(-3022, 9), weight=-0.612321596380797, enabled=True)
# 	DefaultConnectionGene(key=(-3021, 0), weight=-0.5059499188954276, enabled=True)
# 	DefaultConnectionGene(key=(-3021, 1), weight=1.899514188810208, enabled=True)
# 	DefaultConnectionGene(key=(-3021, 2), weight=0.6658101214824649, enabled=True)
# 	DefaultConnectionGene(key=(-3021, 3), weight=-0.09731294482325646, enabled=True)
# 	DefaultConnectionGene(key=(-3021, 4), weight=0.5418283276565092, enabled=True)
# 	DefaultConnectionGene(key=(-3021, 5), weight=-0.5357512043969915, enabled=True)
# 	DefaultConnectionGene(key=(-3021, 6), weight=0.7049573312614735, enabled=True)
# 	DefaultConnectionGene(key=(-3021, 7), weight=-0.06265866807478716, enabled=True)
# 	DefaultConnectionGene(key=(-3021, 8), weight=-0.21041390375217833, enabled=True)
# 	DefaultConnectionGene(key=(-3021, 9), weight=0.2511259079083502, enabled=True)
# 	DefaultConnectionGene(key=(-3020, 0), weight=-1.9854170741940917, enabled=True)
# 	DefaultConnectionGene(key=(-3020, 1), weight=-0.3505313456756407, enabled=True)
# 	DefaultConnectionGene(key=(-3020, 2), weight=0.5359139539461936, enabled=True)
# 	DefaultConnectionGene(key=(-3020, 3), weight=0.7095837059395224, enabled=True)
# 	DefaultConnectionGene(key=(-3020, 4), weight=0.9964393632047417, enabled=True)
# 	DefaultConnectionGene(key=(-3020, 5), weight=-1.837872508417289, enabled=True)
# 	DefaultConnectionGene(key=(-3020, 6), weight=0.726427262714933, enabled=True)
# ...
# 	DefaultConnectionGene(key=(-21, 8), weight=1.3215325148034842, enabled=True)
# 	DefaultConnectionGene(key=(-21, 9), weight=0.932497211543343, enabled=True)
# 	DefaultConnectionGene(key=(-20, 0), weight=0.534306124073986, enabled=True)
# 	DefaultConnectionGene(key=(-20, 1), weight=0.6391093093553388, enabled=True)
# 	DefaultConnectionGene(key=(-20, 2), weight=0.28599155856284986, enabled=True)
# 	DefaultConnectionGene(key=(-20, 3), weight=0.25698807124470163, enabled=True)
# 	DefaultConnectionGene(key=(-20, 4), weight=0.7537085487998125, enabled=True)
# 	DefaultConnectionGene(key=(-20, 5), weight=-1.0714017321244107, enabled=True)
# 	DefaultConnectionGene(key=(-20, 6), weight=0.9284181705631264, enabled=True)
# 	DefaultConnectionGene(key=(-20, 7), weight=0.8822453935569792, enabled=True)
# 	DefaultConnectionGene(key=(-20, 8), weight=0.40465315042882455, enabled=True)
# 	DefaultConnectionGene(key=(-20, 9), weight=-0.7869695526520344, enabled=True)
# 	DefaultConnectionGene(key=(-19, 0), weight=-0.33172543657807213, enabled=True)
# 	DefaultConnectionGene(key=(-19, 1), weight=1.677478190889805, enabled=True)
# 	DefaultConnectionGene(key=(-19, 2), weight=0.5550881657918314, enabled=True)
# 	DefaultConnectionGene(key=(-19, 3), weight=-0.1313081510419799, enabled=True)
# 	DefaultConnectionGene(key=(-19, 4), weight=0.7668346534343787, enabled=True)
# 	DefaultConnectionGene(key=(-19, 5), weight=-1.0556137765664984, enabled=True)
# 	DefaultConnectionGene(key=(-19, 6), weight=1.0954771555161167, enabled=True)
# 	DefaultConnectionGene(key=(-19, 7), weight=-0.3321084224664899, enabled=True)
# 	DefaultConnectionGene(key=(-19, 8), weight=-0.22958049459184873, enabled=True)
# 	DefaultConnectionGene(key=(-19, 9), weight=-1.0727761693575584, enabled=True)
# 	DefaultConnectionGene(key=(-18, 0), weight=-0.3661727584141121, enabled=True)
# 	DefaultConnectionGene(key=(-18, 1), weight=0.6172511829099157, enabled=True)
# 	DefaultConnectionGene(key=(-18, 2), weight=1.5105141952513812, enabled=True)
# 	DefaultConnectionGene(key=(-18, 3), weight=1.6759219987322966, enabled=True)
# 	DefaultConnectionGene(key=(-18, 4), weight=-0.6520683131327043, enabled=True)
# 	DefaultConnectionGene(key=(-18, 5), weight=0.14092813810128824, enabled=True)
# 	DefaultConnectionGene(key=(-18, 6), weight=0.15789268021565017, enabled=True)
# 	DefaultConnectionGene(key=(-18, 7), weight=2.0044555824859196, enabled=True)
# 	DefaultConnectionGene(key=(-18, 8), weight=-0.8102390089203144, enabled=True)
# 	DefaultConnectionGene(key=(-18, 9), weight=-0.21996764012143016, enabled=True)
# 	DefaultConnectionGene(key=(-17, 0), weight=0.4931625643607622, enabled=True)
# 	DefaultConnectionGene(key=(-17, 1), weight=0.2088070734567345, enabled=True)
# 	DefaultConnectionGene(key=(-17, 2), weight=0.5747966936150392, enabled=True)
# 	DefaultConnectionGene(key=(-17, 3), weight=-0.836409440055617, enabled=True)
# 	DefaultConnectionGene(key=(-17, 4), weight=1.4631154822738544, enabled=True)
# 	DefaultConnectionGene(key=(-17, 5), weight=1.1277696085015456, enabled=True)
# 	DefaultConnectionGene(key=(-17, 6), weight=-0.7725597389857558, enabled=True)
# 	DefaultConnectionGene(key=(-17, 7), weight=0.0546447730274493, enabled=True)
# 	DefaultConnectionGene(key=(-17, 8), weight=0.03350964005715078, enabled=True)
# 	DefaultConnectionGene(key=(-17, 9), weight=0.9793966909727961, enabled=True)
# 	DefaultConnectionGene(key=(-16, 0), weight=0.09189007081292616, enabled=True)
# 	DefaultConnectionGene(key=(-16, 1), weight=0.29688879456290723, enabled=True)
# 	DefaultConnectionGene(key=(-16, 2), weight=-0.8827534137920602, enabled=True)
# 	DefaultConnectionGene(key=(-16, 3), weight=0.5336026140233442, enabled=True)
# 	DefaultConnectionGene(key=(-16, 4), weight=0.7166036720601039, enabled=True)
# 	DefaultConnectionGene(key=(-16, 5), weight=0.2507282731386434, enabled=True)
# 	DefaultConnectionGene(key=(-16, 6), weight=-0.9860459554939518, enabled=True)
# 	DefaultConnectionGene(key=(-16, 7), weight=-1.650661952489574, enabled=True)
# 	DefaultConnectionGene(key=(-16, 8), weight=-2.305535117494958, enabled=True)
# 	DefaultConnectionGene(key=(-16, 9), weight=-0.7067428043039381, enabled=True)
# 	DefaultConnectionGene(key=(-15, 0), weight=-0.7811077019967156, enabled=True)
# 	DefaultConnectionGene(key=(-15, 1), weight=0.0853608882298317, enabled=True)
# 	DefaultConnectionGene(key=(-15, 2), weight=-0.6829294611068002, enabled=True)
# 	DefaultConnectionGene(key=(-15, 3), weight=-0.011454882097017217, enabled=True)
# 	DefaultConnectionGene(key=(-15, 4), weight=-0.39501006420670726, enabled=True)
# 	DefaultConnectionGene(key=(-15, 5), weight=1.4487561527630821, enabled=True)
# 	DefaultConnectionGene(key=(-15, 6), weight=1.1953617069473392, enabled=True)
# 	DefaultConnectionGene(key=(-15, 7), weight=0.0821669095571026, enabled=True)
# 	DefaultConnectionGene(key=(-15, 8), weight=0.9630129718774934, enabled=True)
# 	DefaultConnectionGene(key=(-15, 9), weight=1.6948226352374343, enabled=True)
# 	DefaultConnectionGene(key=(-14, 0), weight=-0.5088780812531891, enabled=True)
# 	DefaultConnectionGene(key=(-14, 1), weight=-1.573853232600443, enabled=True)
# 	DefaultConnectionGene(key=(-14, 2), weight=0.4016626931148717, enabled=True)
# 	DefaultConnectionGene(key=(-14, 3), weight=-1.6000588168305208, enabled=True)
# 	DefaultConnectionGene(key=(-14, 4), weight=1.0719646158678837, enabled=True)
# 	DefaultConnectionGene(key=(-14, 5), weight=-0.1449409747156109, enabled=True)
# 	DefaultConnectionGene(key=(-14, 6), weight=-3.1735178130089383, enabled=True)
# 	DefaultConnectionGene(key=(-14, 7), weight=-0.18889638880473028, enabled=True)
# 	DefaultConnectionGene(key=(-14, 8), weight=-0.923907481267095, enabled=True)
# 	DefaultConnectionGene(key=(-14, 9), weight=0.4897780830049272, enabled=True)
# 	DefaultConnectionGene(key=(-13, 0), weight=-0.11772885887831222, enabled=True)
# 	DefaultConnectionGene(key=(-13, 1), weight=0.9190276209420583, enabled=True)
# 	DefaultConnectionGene(key=(-13, 2), weight=-0.5273906461985721, enabled=True)
# 	DefaultConnectionGene(key=(-13, 3), weight=0.7974967428352754, enabled=True)
# 	DefaultConnectionGene(key=(-13, 4), weight=0.7905771812762782, enabled=True)
# 	DefaultConnectionGene(key=(-13, 5), weight=-0.22098862317994217, enabled=True)
# 	DefaultConnectionGene(key=(-13, 6), weight=0.12678309213361194, enabled=True)
# 	DefaultConnectionGene(key=(-13, 7), weight=0.3343675037577134, enabled=True)
# 	DefaultConnectionGene(key=(-13, 8), weight=1.3122282802078558, enabled=True)
# 	DefaultConnectionGene(key=(-13, 9), weight=-0.14653621956985208, enabled=True)
# 	DefaultConnectionGene(key=(-12, 0), weight=-0.4259243589298921, enabled=True)
# 	DefaultConnectionGene(key=(-12, 1), weight=0.2596574533498209, enabled=True)
# 	DefaultConnectionGene(key=(-12, 2), weight=-0.5991981602341311, enabled=True)
# 	DefaultConnectionGene(key=(-12, 3), weight=0.37678546395276735, enabled=True)
# 	DefaultConnectionGene(key=(-12, 4), weight=0.7979809053498745, enabled=True)
# 	DefaultConnectionGene(key=(-12, 5), weight=0.09127008394817715, enabled=False)
# 	DefaultConnectionGene(key=(-12, 6), weight=-0.7702126801736235, enabled=True)
# 	DefaultConnectionGene(key=(-12, 7), weight=-0.28015332128050285, enabled=True)
# 	DefaultConnectionGene(key=(-12, 8), weight=0.3393428366408138, enabled=True)
# 	DefaultConnectionGene(key=(-12, 9), weight=-0.951851810795143, enabled=True)
# 	DefaultConnectionGene(key=(-11, 0), weight=0.3643446955887096, enabled=True)
# 	DefaultConnectionGene(key=(-11, 1), weight=1.619733182241954, enabled=True)
# 	DefaultConnectionGene(key=(-11, 2), weight=-0.6821567681167021, enabled=True)
# 	DefaultConnectionGene(key=(-11, 3), weight=0.02693813772250392, enabled=True)
# 	DefaultConnectionGene(key=(-11, 4), weight=2.7415650238699127, enabled=True)
# 	DefaultConnectionGene(key=(-11, 5), weight=0.729926852585266, enabled=True)
# 	DefaultConnectionGene(key=(-11, 6), weight=-0.5545153682315711, enabled=True)
# 	DefaultConnectionGene(key=(-11, 7), weight=-0.480233032302983, enabled=True)
# 	DefaultConnectionGene(key=(-11, 8), weight=-0.24015634510290165, enabled=True)
# 	DefaultConnectionGene(key=(-11, 9), weight=0.6897692169042893, enabled=False)
# 	DefaultConnectionGene(key=(-10, 0), weight=-0.4635364995513467, enabled=True)
# 	DefaultConnectionGene(key=(-10, 1), weight=-0.1824034237856624, enabled=True)
# 	DefaultConnectionGene(key=(-10, 2), weight=0.6703745746619506, enabled=True)
# 	DefaultConnectionGene(key=(-10, 3), weight=-1.2855405728031963, enabled=True)
# 	DefaultConnectionGene(key=(-10, 4), weight=0.2903825812460644, enabled=True)
# 	DefaultConnectionGene(key=(-10, 5), weight=1.0236407069580704, enabled=True)
# 	DefaultConnectionGene(key=(-10, 6), weight=1.4769752798524334, enabled=True)
# 	DefaultConnectionGene(key=(-10, 7), weight=0.0692676325285515, enabled=True)
# 	DefaultConnectionGene(key=(-10, 8), weight=-0.8526886057889551, enabled=True)
# 	DefaultConnectionGene(key=(-10, 9), weight=-0.5429827593701245, enabled=True)
# 	DefaultConnectionGene(key=(-9, 0), weight=-0.028498803991046012, enabled=True)
# 	DefaultConnectionGene(key=(-9, 1), weight=0.6749548065882554, enabled=True)
# 	DefaultConnectionGene(key=(-9, 2), weight=0.034364999402847624, enabled=True)
# 	DefaultConnectionGene(key=(-9, 3), weight=1.6434833895715748, enabled=True)
# 	DefaultConnectionGene(key=(-9, 4), weight=0.48435287147639333, enabled=True)
# 	DefaultConnectionGene(key=(-9, 5), weight=-0.06840981796380205, enabled=True)
# 	DefaultConnectionGene(key=(-9, 6), weight=-0.5926836675518586, enabled=True)
# 	DefaultConnectionGene(key=(-9, 7), weight=-0.5059365783996248, enabled=True)
# 	DefaultConnectionGene(key=(-9, 8), weight=0.7100610006808956, enabled=True)
# 	DefaultConnectionGene(key=(-9, 9), weight=1.8950131597000517, enabled=True)
# 	DefaultConnectionGene(key=(-8, 0), weight=-0.6746883149725517, enabled=True)
# 	DefaultConnectionGene(key=(-8, 1), weight=2.675376670046313, enabled=True)
# 	DefaultConnectionGene(key=(-8, 2), weight=0.38673959736681596, enabled=True)
# 	DefaultConnectionGene(key=(-8, 3), weight=-0.08786788413064359, enabled=True)
# 	DefaultConnectionGene(key=(-8, 4), weight=2.2000525354945712, enabled=True)
# 	DefaultConnectionGene(key=(-8, 5), weight=1.616157315997411, enabled=True)
# 	DefaultConnectionGene(key=(-8, 6), weight=-0.9186145600669052, enabled=True)
# 	DefaultConnectionGene(key=(-8, 7), weight=-0.8448747450224035, enabled=True)
# 	DefaultConnectionGene(key=(-8, 8), weight=-0.6354699552612562, enabled=True)
# 	DefaultConnectionGene(key=(-8, 9), weight=1.4775194941665275, enabled=True)
# 	DefaultConnectionGene(key=(-7, 0), weight=-0.04274557694738248, enabled=True)
# 	DefaultConnectionGene(key=(-7, 1), weight=1.3220066140616096, enabled=True)
# 	DefaultConnectionGene(key=(-7, 2), weight=0.5121986945964521, enabled=True)
# 	DefaultConnectionGene(key=(-7, 3), weight=-0.892216683337242, enabled=True)
# 	DefaultConnectionGene(key=(-7, 4), weight=-0.5579268809009248, enabled=True)
# 	DefaultConnectionGene(key=(-7, 5), weight=1.044506048512968, enabled=True)
# 	DefaultConnectionGene(key=(-7, 6), weight=1.4113672025516586, enabled=True)
# 	DefaultConnectionGene(key=(-7, 7), weight=0.8465376933012789, enabled=True)
# 	DefaultConnectionGene(key=(-7, 8), weight=-0.7132847463926714, enabled=True)
# 	DefaultConnectionGene(key=(-7, 9), weight=-0.4531582611358841, enabled=True)
# 	DefaultConnectionGene(key=(-6, 0), weight=-0.8057554021505743, enabled=True)
# 	DefaultConnectionGene(key=(-6, 1), weight=-1.5125194942155327, enabled=True)
# 	DefaultConnectionGene(key=(-6, 2), weight=-1.8623980024594804, enabled=True)
# 	DefaultConnectionGene(key=(-6, 3), weight=0.2927836513467707, enabled=True)
# 	DefaultConnectionGene(key=(-6, 4), weight=-0.4441812593297007, enabled=True)
# 	DefaultConnectionGene(key=(-6, 5), weight=-0.07349537196541242, enabled=True)
# 	DefaultConnectionGene(key=(-6, 6), weight=0.1419459819870378, enabled=True)
# 	DefaultConnectionGene(key=(-6, 7), weight=0.4035768093437071, enabled=True)
# 	DefaultConnectionGene(key=(-6, 8), weight=-0.36534869811332993, enabled=True)
# 	DefaultConnectionGene(key=(-6, 9), weight=0.9577568872801996, enabled=True)
# 	DefaultConnectionGene(key=(-5, 0), weight=0.38644092308290456, enabled=True)
# 	DefaultConnectionGene(key=(-5, 1), weight=-0.5429945254738143, enabled=True)
# 	DefaultConnectionGene(key=(-5, 2), weight=-0.69520852181552, enabled=True)
# 	DefaultConnectionGene(key=(-5, 3), weight=-1.0302574216941576, enabled=True)
# 	DefaultConnectionGene(key=(-5, 4), weight=-0.29027417070650957, enabled=True)
# 	DefaultConnectionGene(key=(-5, 5), weight=0.2573870246641403, enabled=True)
# 	DefaultConnectionGene(key=(-5, 6), weight=-0.9876818902674656, enabled=True)
# 	DefaultConnectionGene(key=(-5, 7), weight=0.07184958246198857, enabled=True)
# 	DefaultConnectionGene(key=(-5, 8), weight=-1.3574022740932234, enabled=True)
# 	DefaultConnectionGene(key=(-5, 9), weight=1.4075983200748996, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=0.5216422067508991, enabled=True)
# 	DefaultConnectionGene(key=(-4, 1), weight=-0.06019141146326923, enabled=True)
# 	DefaultConnectionGene(key=(-4, 2), weight=1.2963576017441785, enabled=True)
# 	DefaultConnectionGene(key=(-4, 3), weight=-1.6012373765177315, enabled=True)
# 	DefaultConnectionGene(key=(-4, 4), weight=0.7868436294702896, enabled=True)
# 	DefaultConnectionGene(key=(-4, 5), weight=-1.2565595009942194, enabled=True)
# 	DefaultConnectionGene(key=(-4, 6), weight=-0.894473053093343, enabled=True)
# 	DefaultConnectionGene(key=(-4, 7), weight=-0.18720725596012672, enabled=True)
# 	DefaultConnectionGene(key=(-4, 8), weight=0.21552125723192986, enabled=True)
# 	DefaultConnectionGene(key=(-4, 9), weight=0.9672965214947513, enabled=True)
# 	DefaultConnectionGene(key=(-3, 0), weight=0.6057849406182738, enabled=True)
# 	DefaultConnectionGene(key=(-3, 1), weight=-0.5385197081791047, enabled=True)
# 	DefaultConnectionGene(key=(-3, 2), weight=-1.614772973851712, enabled=True)
# 	DefaultConnectionGene(key=(-3, 3), weight=-1.6375051994917014, enabled=True)
# 	DefaultConnectionGene(key=(-3, 4), weight=0.8199826524537581, enabled=True)
# 	DefaultConnectionGene(key=(-3, 5), weight=2.021669999327508, enabled=True)
# 	DefaultConnectionGene(key=(-3, 6), weight=0.26902696852183955, enabled=True)
# 	DefaultConnectionGene(key=(-3, 7), weight=1.5919644018849204, enabled=True)
# 	DefaultConnectionGene(key=(-3, 8), weight=0.3008557070979464, enabled=True)
# 	DefaultConnectionGene(key=(-3, 9), weight=0.23632428838221786, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=0.3855533216378172, enabled=True)
# 	DefaultConnectionGene(key=(-2, 1), weight=-0.5746379007789609, enabled=True)
# 	DefaultConnectionGene(key=(-2, 2), weight=-2.1090057742949577, enabled=True)
# 	DefaultConnectionGene(key=(-2, 3), weight=0.49332389367797297, enabled=True)
# 	DefaultConnectionGene(key=(-2, 4), weight=1.2210989375119667, enabled=True)
# 	DefaultConnectionGene(key=(-2, 5), weight=0.5553305816596018, enabled=True)
# 	DefaultConnectionGene(key=(-2, 6), weight=0.2799755862514012, enabled=True)
# 	DefaultConnectionGene(key=(-2, 7), weight=0.22853113220064314, enabled=True)
# 	DefaultConnectionGene(key=(-2, 8), weight=1.064579007020006, enabled=True)
# 	DefaultConnectionGene(key=(-2, 9), weight=0.25183690587127483, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), weight=-0.5031201643475454, enabled=True)
# 	DefaultConnectionGene(key=(-1, 1), weight=-1.3230915346353556, enabled=True)
# 	DefaultConnectionGene(key=(-1, 2), weight=-0.46258514570419873, enabled=True)
# 	DefaultConnectionGene(key=(-1, 3), weight=1.0209612672587245, enabled=True)
# 	DefaultConnectionGene(key=(-1, 4), weight=0.28277170638170446, enabled=True)
# 	DefaultConnectionGene(key=(-1, 5), weight=1.5148542715241278, enabled=True)
# 	DefaultConnectionGene(key=(-1, 6), weight=-0.14422611564632326, enabled=True)
# 	DefaultConnectionGene(key=(-1, 7), weight=0.21588294714910147, enabled=True)
# 	DefaultConnectionGene(key=(-1, 8), weight=-2.468986056848536, enabled=True)
# 	DefaultConnectionGene(key=(-1, 9), weight=0.6053166556404432, enabled=True)
# 	DefaultConnectionGene(key=(11, 8), weight=0.19018892570489593, enabled=True)
# 	DefaultConnectionGene(key=(12, 1), weight=0.2039255550467154, enabled=True)

# %%
y_pred = neat_genome.predict(X_test_fl)

# %%
print(classification_report(y_test.ravel(), y_pred.ravel()))

# %%
results.items()

# %%
fitness = [i['fitness'] for i in results.values()]
pop_avg_fitness = [i['pop_avg_fitness'] for i in results.values()]

fig,ax = plt.subplots(figsize=(15,8))

plt.plot(np.linspace(1,len(fitness),len(fitness)),
         fitness,
         label="Fitness")
plt.plot(np.linspace(1,len(pop_avg_fitness),len(pop_avg_fitness)),
         pop_avg_fitness,
         label="Population's average fitness")

plt.xlabel("Generation")
plt.ylabel("Fitness")

plt.legend()

plt.xticks(np.linspace(1,len(fitness),len(pop_avg_fitness)))

plt.savefig("figures/fitness.png")

plt.plot()

# %%
stdev = [i['stdev'] for i in results.values()]

fig,ax = plt.subplots(figsize=(15,8))

plt.plot(np.linspace(1,len(stdev),len(stdev)),
         stdev,
         label="Standard deviation")

plt.xlabel("Generation")
plt.ylabel("Standard deviation")

plt.legend()

plt.xticks(np.linspace(1,len(stdev),len(stdev)))

plt.savefig("figures/stdev.png")

plt.plot()
